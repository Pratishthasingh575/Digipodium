# %%
x=100

# %%
if x==100 :
    print("x is greater then 10")
# Out:
# x is greater then 10

# %%
name ='william shakespeare'

# %%
if 'spear'in name:
    print('spear found in name')
# Out:
# spear found in name

# %%
age =int (input('what is your:'))
if age>=18:
    print('you are an adult')
    print('you can vote')
else:
    print('you are child')
    print ('you can not vote')
    print('you can vote in ',18-age,'years')
# Out:
# you are child
# you can not vote
# you can vote in  16 years

# %%
#if elif else ladder
print('welcome to the ice cream shop')
flavour =input('what flavour do you want?')
if flavour=='vanilla':
    print ('here is your vanilla')
elif flavour=='chocolate':
     print ('here is your chocolate')
elif flavour=='strawberry':
      print ('here is your strawberry')
else:
     print('sorry we do not have ',flavour,'flavour')
# Out:
# welcome to the ice cream shop
# sorry we do not have  oreo flavour
